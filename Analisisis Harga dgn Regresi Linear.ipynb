# %%
# Import modul yang dibutuhkan
import pandas as pd
import numpy as np
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# Melihat 5 value tertinggi
dataframe =  pd.read_csv("C:/Users/asus/Anaconda3/Dhoni/Project/My Data Science/Melbourne_housing_extra_data.csv")
dataframe.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.8014    144.9958  Northern Metropolitan
# 1        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 3        NaN        Yarra  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
dataframe.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
# Mengubah format dataframe menjadi tanggal
dataframe["Date"] = pd.to_datetime(dataframe["Date"],dayfirst=True)

# %%
# Mencari rata2 pertahun
len(dataframe["Date"].unique())/4
# Out:
# 13.0

# %%
# Mencari standar deviasi, jumlah nilai, dan mencari rata2 dari dataframe yang sudah diubah menjadi format tanggal 
var = dataframe[dataframe["Type"]=="h"].sort_values("Date", ascending=False).groupby("Date").std()
count = dataframe[dataframe["Type"]=="h"].sort_values("Date", ascending=False).groupby("Date").count()
mean = dataframe[dataframe["Type"]=="h"].sort_values("Date", ascending=False).groupby("Date").mean()

# %% [markdown]
# **Memulai visualisasi**

# %%
# Visualisasi rata2 perubahan harga mulai dari bulan Maret 2016 sampai bulan Juli 2017
mean["Price"].plot(yerr=var["Price"],ylim=(400000,1500000))

# %%
# Visualisasi jumlah harga yang berubah mulai dari bulan Maret 2016 sampai bulan Juli 2017
count["Price"].plot(yerr=var["Price"],ylim=(400000,1500000))

# %%
# membuat rata2 dan plotting data
means = dataframe[(dataframe["Type"]=="h") & (dataframe["Distance"]<13)].sort_values("Date", ascending=False).groupby("Date").mean()
errors = dataframe[(dataframe["Type"]=="h") & (dataframe["Distance"]<13)].sort_values("Date", ascending=False).groupby("Date").std()

# %%
# Menari column yang tidak dibutuhkan
means.columns
# Out:
# Index(['Rooms', 'Price', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude',
#        'Propertycount'],
#       dtype='object')

# %%
# Menghapus column dengan fungsi drop
# Memplotting dengan ax.plot
means.drop(["Price",
            "Postcode",
            
           "Longtitude","Lattitude",
           "Distance","BuildingArea", "Propertycount","Landsize","YearBuilt"],axis=1).plot(yerr=errors)

# %%
# Mengurutkan data berdasarkan tanggal  
dataframe[dataframe["Type"]=="h"].sort_values("Date", ascending=False).groupby("Date").mean()
# Out:
#                Rooms         Price   Distance     Postcode  Bedroom2  \
# Date
# 2016-01-28  3.500000  1.205000e+06  10.100000  3126.500000  3.500000
# 2016-02-04  2.958333  1.068888e+06  10.245833  3091.083333  2.842105
# 2016-04-16  3.271552  1.224499e+06   8.964655  3091.806034  3.089947
# 2016-04-23  3.181818  1.087059e+06   8.721818  3078.445455  3.034483
# 2016-05-07  3.279152  1.285205e+06   8.995760  3099.922261  3.164502
# 2016-05-14  3.191176  1.171023e+06   8.664216  3093.058824  3.089286
# 2016-05-22  3.330144  1.218111e+06   9.051675  3093.019139  3.165680
# 2016-05-28  3.452055  1.366617e+06   9.108219  3102.407534  3.220339
# 2016-06-04  3.356164  1.242345e+06   9.271233  3096.415525  3.220339
# 2016-06-12  3.272727  1.229932e+06   8.898182  3090.690909  3.177778
# 2016-06-18  3.354167  1.325222e+06   8.996528  3100.711806  3.207048
# 2016-06-27  3.262009  1.143939e+06   9.433188  3084.393013  3.157303
# 2016-07-16  3.114504  1.050945e+06   9.626718  3075.984733  3.009434
# 2017-07-01 -37.804181  145.009752    7296.811209
# 2017-07-08 -37.804749  145.005992    7816.779310
# 2017-07-15 -37.820668  145.021718    7693.822064
# 2017-07-22 -37.797749  144.978511    7595.591054
# 2017-07-29 -37.808985  144.999807    7912.037855
# 2017-08-12 -37.803536  145.013760    7438.498708

# %%
# Menampilkan lengkap keseluruhan data berdasarkan Suburb
pd.set_eng_float_format(accuracy=1, use_eng_prefix=True)
dataframe[(dataframe["Type"]=="h") & 
          (dataframe["Distance"]<14) &
          (dataframe["Distance"]>13.7)].sort_values("Date", ascending=False).dropna().groupby(["Suburb","SellerG"]).mean()
# Out:
#                                  Rooms   Price  Distance  Postcode  Bedroom2  \
# Suburb            SellerG
# Albion            Barry            2.3  735.0k      13.9      3.0k       2.3
#                   Bells            3.0  782.0k      13.9      3.0k       3.3
#                   Sweeney          3.0  596.5k      13.9      3.0k       3.0
#                   hockingstuart    3.0  730.0k      13.9      3.0k       3.0
# Altona            Barlow           3.0    1.1M      13.8      3.0k       3.0
#                   Compton          2.0  535.6k      13.8      3.0k       2.0
#                   Greg             3.8    1.1M      13.8      3.0k       3.8
#                   hockingstuart    3.0  928.8k      13.8      3.0k       3.0
# Bentleigh East    Beller           3.0  900.0k      13.9      3.2k       3.0
#                   Buxton           3.3    1.1M      13.9      3.2k       3.3
#                   C21              3.3  907.7k      13.9      3.2k       3.3
#                   First            4.0    1.0M      13.9      3.2k       3.0
#                   Gary             3.5    1.2M      13.9      3.2k       3.5
#                   Hodges           4.2    1.3M      13.9      3.2k       4.0
#                   Marshall         4.0    1.4M      13.9      3.2k       4.0
#                   Nick             3.0    1.0M      13.9      3.2k       3.0
#                   RT               4.0    1.2M      13.9      3.2k       4.0
#                   Ray              3.0  896.7k      13.9      3.2k       3.0
#                   Woodards         3.2    1.1M      13.9      3.2k       3.2
#                   hockingstuart    3.7    1.4M      13.9      3.2k       3.7
# Doncaster         Barry            3.6    1.4M      13.9      3.1k       3.6
#                   Fletchers        3.0    1.2M      13.9      3.1k       3.0
#                   Jellis           3.9    1.5M      13.9      3.1k       3.9
#                   Philip           3.5    1.4M      13.9      3.1k       3.5
#                   RW               4.0    1.4M      13.9      3.1k       4.0
#                   Ray              3.4    1.2M      13.9      3.1k       3.3
#                   Vic              3.0    1.1M      13.9      3.1k       3.0
#                   hockingstuart    3.5    1.5M      13.9      3.1k       3.0
# Hampton           Hodges           4.0    2.6M      13.8      3.2k       4.0
# Templestowe Lower Barry            3.8    1.2M      13.8      3.1k       3.8
#                   Jellis           3.6    1.3M      13.8      3.1k       3.6
#                   Mason            4.0  790.0k      13.8      3.1k       4.0
#                   Philip           3.3    1.0M      13.8      3.1k       3.3
#                   RT               3.0  650.0k      13.8      3.1k       3.0
#                   Zahn             4.0    1.2M      13.8      3.1k       4.0
#                   hockingstuart    4.5  875.0k      13.8      3.1k       4.5
# Viewbank          Barry            3.0  770.0k      13.8      3.1k       3.0
#                   Buckingham       3.0  880.0k      13.8      3.1k       3.0
#                   Darren           4.0    1.0M      13.8      3.1k       4.0
#                   Fletchers        4.0    1.2M      13.8      3.1k       4.0
#                   Miles            3.6  903.0k      13.8      3.1k       3.8
#                   Morrison         3.0  820.0k      13.8      3.1k       3.0
#                   Nelson           4.0  981.7k      13.8      3.1k       4.0
#                   Ray              3.0  765.0k      13.8      3.1k       3.0
#
#                                  Bathroom  Car  Landsize  BuildingArea  \
# Suburb            SellerG
# Albion            Barry               1.0  1.0     634.3         118.0
#                   Bells               1.3  2.3     741.0         126.0
#                   Sweeney             1.5  1.5     651.0         106.0
#                   hockingstuart       2.0  3.0     628.0         140.0
# Altona            Barlow              1.0  2.0     506.0         120.0
#                   Compton             1.0  1.0     154.0          91.0
#                   Greg                2.3  2.8     666.5         198.3
#                   hockingstuart       1.2  2.2     700.8          84.8
# Bentleigh East    Beller              1.0  3.0     780.0         140.0
#                   Buxton              1.6  1.8     521.2         147.5
#                   C21                 1.7  2.3     467.7         150.3
#                   First               1.0  2.0     610.0         160.0
#                   Gary                1.8  1.8     931.0         167.2
#                   Hodges              1.8  1.4     568.6         189.8
#                   Marshall            1.0  1.0     582.0         151.0
#                   Nick                1.0  2.0     596.0         144.0
#                   RT                  2.0  2.0     620.0         158.0
#                   Ray                 2.0  1.7     345.7         128.7
#                   Woodards            1.2  2.2     567.1         128.8
#                   hockingstuart       2.0  2.3     605.5         208.2
# Doncaster         Barry               2.1  2.1     601.4         183.4
#                   Fletchers           2.0  2.0     900.0         195.0
#                   Jellis              2.2  2.1     673.8         220.7
#                   Philip              2.0  2.0     726.0         146.0
#                   RW                  3.0  2.0     650.0         261.0
#                   Ray                 1.7  1.6     719.0         157.9
#                   Vic                 2.0  2.0     771.0         169.0
#                   hockingstuart       2.0  2.0     872.0         195.5
# Hampton           Hodges              2.0  2.0     726.0         200.0
# Templestowe Lower Barry               1.9  2.2     707.6         184.2
#                   Jellis              1.7  1.9     694.4         186.3
#                   Mason               2.0  5.0     671.0         180.0
#                   Philip              1.7  2.0     631.0         148.7
#                   RT                  1.0  2.0     327.0         120.0
#                   Zahn                2.0  2.0     657.0         221.0
#                   hockingstuart       3.0  3.0     764.0         249.5
# Viewbank          Barry               2.0  2.0     577.0         135.0
#                   Buckingham          2.0  4.0     704.0         167.0
#                   Darren              2.0  1.0     696.0         183.0
#                   Fletchers           2.0  3.0     780.0         217.0
#                   Miles               2.0  1.8     744.8         135.8
#                   Morrison            2.0  2.0     628.0         177.0
#                   Nelson              2.0  2.0     629.7         190.7
#                   Ray                 1.0  2.0     608.0         138.0
#
#                                  YearBuilt  Lattitude  Longtitude  \
# Suburb            SellerG
# Albion            Barry               1.9k      -37.8       144.8
#                   Bells               2.0k      -37.8       144.8
#                   Sweeney             1.9k      -37.8       144.8
#                   hockingstuart       2.0k      -37.8       144.8
# Altona            Barlow              1.9k      -37.9       144.8
#                   Compton             2.0k      -37.9       144.8
#                   Greg                2.0k      -37.9       144.8
#                   hockingstuart       2.0k      -37.9       144.8
# Bentleigh East    Beller              1.9k      -37.9       145.1
#                   Buxton              2.0k      -37.9       145.1
#                   C21                 2.0k      -37.9       145.1
#                   First               2.0k      -37.9       145.1
#                   Gary                1.5k      -37.9       145.0
#                   Hodges              2.0k      -37.9       145.1
#                   Marshall            2.0k      -37.9       145.1
#                   Nick                2.0k      -37.9       145.1
#                   RT                  2.0k      -37.9       145.1
#                   Ray                 2.0k      -37.9       145.1
#                   Woodards            2.0k      -37.9       145.1
#                   hockingstuart       2.0k      -37.9       145.1
# Doncaster         Barry               2.0k      -37.8       145.1
#                   Fletchers           2.0k      -37.8       145.1
#                   Jellis              2.0k      -37.8       145.1
#                   Philip              2.0k      -37.8       145.1
#                   RW                  2.0k      -37.8       145.1
#                   Ray                 2.0k      -37.8       145.1
#                   Vic                 2.0k      -37.8       145.1
#                   hockingstuart       2.0k      -37.8       145.1
# Hampton           Hodges              1.9k      -37.9       145.0
# Templestowe Lower Barry               2.0k      -37.8       145.1
#                   Jellis              2.0k      -37.8       145.1
#                   Mason               2.0k      -37.8       145.1
#                   Philip              2.0k      -37.8       145.1
#                   RT                  2.0k      -37.8       145.1
#                   Zahn                2.0k      -37.8       145.1
#                   hockingstuart       2.0k      -37.8       145.1
# Viewbank          Barry               2.0k      -37.7       145.1
#                   Buckingham          2.0k      -37.7       145.1
#                   Darren              2.0k      -37.7       145.1
#                   Fletchers           2.0k      -37.7       145.1
#                   Miles               2.0k      -37.7       145.1
#                   Morrison            2.0k      -37.7       145.1
#                   Nelson              2.0k      -37.7       145.1
#                   Ray                 2.0k      -37.7       145.1
#
#                                  Propertycount
# Suburb            SellerG
# Albion            Barry                   2.2k
#                   Bells                   2.2k
#                   Sweeney                 2.2k
#                   hockingstuart           2.2k
# Altona            Barlow                  5.3k
#                   Compton                 5.3k
#                   Greg                    5.3k
#                   hockingstuart           5.3k
# Bentleigh East    Beller                 11.0k
#                   Buxton                 11.0k
#                   C21                    11.0k
#                   First                  11.0k
#                   Gary                   11.0k
#                   Hodges                 11.0k
#                   Marshall               11.0k
#                   Nick                   11.0k
#                   RT                     11.0k
#                   Ray                    11.0k
#                   Woodards               11.0k
#                   hockingstuart          11.0k
# Doncaster         Barry                   9.0k
#                   Fletchers               9.0k
#                   Jellis                  9.0k
#                   Philip                  9.0k
#                   RW                      9.0k
#                   Ray                     9.0k
#                   Vic                     9.0k
#                   hockingstuart           9.0k
# Hampton           Hodges                  5.5k
# Templestowe Lower Barry                   5.4k
#                   Jellis                  5.4k
#                   Mason                   5.4k
#                   Philip                  5.4k
#                   RT                      5.4k
#                   Zahn                    5.4k
#                   hockingstuart           5.4k
# Viewbank          Barry                   2.7k
#                   Buckingham              2.7k
#                   Darren                  2.7k
#                   Fletchers               2.7k
#                   Miles                   2.7k
#                   Morrison                2.7k
#                   Nelson                  2.7k
#                   Ray                     2.7k

# %%
sns.kdeplot(dataframe[(dataframe["Suburb"]=="Northcote")
         & (dataframe["Type"]=="u")
         & (dataframe["Rooms"] == 2)]["Price"])
# Out:
# C:\Users\asus\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\asus\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
plt.figure(figsize=(20,15))
my_axis = sns.kdeplot(dataframe["Price"][((dataframe["Type"]=="u") &
                                (dataframe["Distance"]>8) &
                                (dataframe["Distance"]<10) &
                                (dataframe["Rooms"] > 2)#&
                                #(dataframe["Price"] < 1000000)
                               )])
my_axis.axis(xmin=0, xmax=2000000)
# Out:
# (0, 2000000, 0.0, 1.8857262931775313e-06)

# %%
sns.lmplot("Distance","Price",dataframe[(dataframe["Rooms"]<=4) & 
                                         (dataframe["Rooms"]> 2) & 
                                        (dataframe["Type"]=="h") &
                                        (dataframe["Price"]< 1000000)
                                       ].dropna(),hue="Rooms", size=10)
# Out:
# C:\Users\asus\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
dataframe[(dataframe["Rooms"]>2) & (dataframe["Type"] == "h")& (dataframe["Landsize"] <5000)][["Landsize","Distance"]].dropna().groupby("Distance").mean().plot()

# %% [markdown]
# **Memulai prediksi dengan model Linear Regression**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from datetime import date

# %%
dataframe.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
dataframe_dr = dataframe.dropna().sort_values("Date")
dataframe_dr = dataframe_dr[dataframe_dr["Type"]=="h"]
dataframe_dr = dataframe_dr

all_Data = []
days_since_start = [(x - dataframe_dr["Date"].min()).days for x in dataframe_dr["Date"]]
dataframe_dr["Days"] = days_since_start

# %%
# Dummies data sesuai kebutuhan yang ingin di lihat prediksi

#suburb_dummies = pd.get_dummies(dataframe_dr[["Suburb", "Type", "Method"]])
suburb_dummies = pd.get_dummies(dataframe_dr[["Type", "Method"]])
#suburb_dummies = pd.get_dummies(dataframe_dr[[ "Type"]])
#suburb_dummies = pd.get_dummies(dataframe_dr[["Suburb", "Method"]])

# %%
all_Data = dataframe_dr.drop(["Address","Price","Date", "SellerG","Suburb","Type","Method","CouncilArea","Regionname"],axis=1).join(suburb_dummies)
X = all_Data
y = dataframe_dr["Price"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
print(lr.intercept_)
# Out:
# -143602021.93563932

# %%
X.columns
# Out:
# Index(['Rooms', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude',
#        'Propertycount', 'Days', 'Type_h', 'Method_PI', 'Method_S', 'Method_SA',
#        'Method_SP', 'Method_VB'],
#       dtype='object')

# %%
coeff_df = pd.DataFrame(lr.coef_,X.columns,columns=['Coefficient'])
ranked_suburbs = coeff_df.sort_values("Coefficient", ascending = False)
ranked_suburbs
# Out:
#                Coefficient
# Longtitude          595.8k
# Rooms               263.0k
# Bathroom            211.9k
# Car                  59.4k
# Method_S             55.4k
# Method_VB            18.1k
# Postcode              1.8k
# Days                 268.0
# YearBuilt            108.5
# Landsize              88.4
# BuildingArea          26.8
# Type_h             -203.7p
# Propertycount         -3.7
# Method_PI           -330.2
# Method_SP           -35.1k
# Method_SA           -38.0k
# Bedroom2            -41.4k
# Distance            -67.3k
# Lattitude            -1.4M

# %% [markdown]
# **Memulai evaluasi dari model Linear Regression**

# %%
predictions = lr.predict(X_test)

# %%
plt.scatter(y_test, predictions)
plt.ylim([200000,1000000])
plt.xlim([200000,1000000])
# Out:
# (200000, 1000000)

# %%
sns.distplot((y_test-predictions),bins=50)

# %%
from sklearn import metrics

# %%
print("MAE:", metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 337360.5611688259
# MSE: 282646237029.4754
# RMSE: 531644.8410635388
